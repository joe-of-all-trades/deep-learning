# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
# train_words = # The final subsampled word list
from collections import Counter
import random

word_count = Counter(int_words)
total_words = len(int_words)

thresh = 1e-5
prob = {word: 1 - np.sqrt( thresh / (word_count[word] / total_words)) for word in word_count}
# 0.75 has a 75% probability to be larger than a number randonmly drawn from the interval (0,1)
train_words = [word for word in int_words if (1 - prob[word]) > random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random
import numpy as np

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    n = random.randint(1, window_size+1)
    return list(set(words[np.max([0, idx-n]):idx] + words[idx+1:idx+n+1]))    
    # belowe is the solution 
    #R = np.random.randint(1, window_size+1)
    #start = idx - R if (idx - R) > 0 else 0
    #stop = idx + R
    #target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) 
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
tf.__version__
# Out:
# '1.2.0'

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:

            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6305 0.0275 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6174 0.0252 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5092 0.0259 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6095 0.0263 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5063 0.0267 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5394 0.0276 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5388 0.0282 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5369 0.0275 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4807 0.0268 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4136 0.0248 sec/batch
# Nearest to often: gyges, theory, warbeck, manhunt, brigham, during, candidacy, solver,
# Nearest to as: sucessful, mooney, puppies, evolves, performing, a, selig, briefing,
# Nearest to called: indoctrination, hedging, age, plummer, nikolai, coercive, embouchure, present,
# Nearest to states: summa, las, saragossa, anonymously, cathari, jeffers, biola, modernism,
# Nearest to are: adheres, afrikaner, wow, kj, adoption, hafez, cosmodrome, maud,
# Nearest to more: cinderella, eia, anz, subpixel, rohypnol, burma, storyboard, adjudication,
# Nearest to between: scales, astigmatism, macroevolution, og, tegmark, hbf, brazil, contentious,
# Nearest to time: namesake, theatres, insecurity, devote, garret, daglow, remuneration, mermaid,
# Nearest to road: cuttlefish, remarking, rector, poststructuralist, implicate, dixon, feeling, islanders,
# Nearest to instance: selectivity, dressers, wanda, ulansey, desoto, appointments, wojew, volatile,
# Nearest to derived: granada, homeowners, direct, wight, bolder, marcello, maser, unequalled,
# Nearest to operating: fiberglass, jeep, vegan, judeans, sampler, tver, gull, goodyear,
# Nearest to placed: dagda, distance, even, awe, husky, mashad, staying, kj,
# Nearest to troops: avenue, bram, slapped, ima, priestly, sardar, hermeneutic, mascarenhas,
# Nearest to professional: calves, perutz, lvl, friedrich, residue, ishmael, intramuscular, gillmor,
# Nearest to universe: drown, behave, eram, bioko, greens, inhabited, tobacco, slapped,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4857 0.0253 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3666 0.0258 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3378 0.0273 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2277 0.0263 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1516 0.0247 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1418 0.0264 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1054 0.0265 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0847 0.0272 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9859 0.0262 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9671 0.0297 sec/batch
# Nearest to often: theory, during, writing, traditional, brigham, adventures, stopped, taylor,
# Nearest to as: sucessful, mooney, evolves, performing, die, domain, traditional, mildly,
# Nearest to called: age, indoctrination, central, hedging, present, nikolai, embouchure, plummer,
# Nearest to states: las, lake, saragossa, summa, age, skyscrapers, anonymously, ep,
# Nearest to are: adheres, adoption, predominant, kj, praised, afrikaner, additions, rapid,
# Nearest to more: cinderella, rohypnol, eia, anz, burma, consultant, era, gypsy,
# Nearest to between: scales, of, contentious, amount, macroevolution, mental, ones, brazil,
# Nearest to time: theatres, insecurity, garret, namesake, daglow, estimate, consumed, fantastic,
# Nearest to road: rector, cuttlefish, feeling, differing, restrict, graduate, islanders, work,
# Nearest to instance: equation, desoto, statements, hops, recognizable, ulansey, wanda, compass,
# Nearest to derived: direct, homeowners, granada, military, lives, grouping, wight, primal,
# Nearest to operating: jeep, view, provincial, goodyear, judeans, spartacist, theoretic, full,
# Nearest to placed: distance, even, staying, dagda, awe, kj, proportions, mashad,
# Nearest to troops: avenue, bram, slapped, priestly, encroached, ima, wwii, mascarenhas,
# Nearest to professional: calves, gregorian, friedrich, concepts, ishmael, perutz, lvl, translation,
# Nearest to universe: drown, behave, inhabited, eram, greens, slapped, shemot, tobacco,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8992 0.0272 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8891 0.0245 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8674 0.0264 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8237 0.0285 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8291 0.0280 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8258 0.0282 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7874 0.0282 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7817 0.0258 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7646 0.0266 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7895 0.0254 sec/batch
# Nearest to often: theory, writing, stopped, adventures, extended, taylor, during, traditional,
# Nearest to as: mildly, falklands, coalescence, sucessful, upper, puppies, nordic, gymnasium,
# Nearest to called: indoctrination, age, hedging, coercive, plummer, reestablishing, nikolai, geologic,
# Nearest to states: saragossa, las, anonymously, summa, biola, patriarchy, jeffers, prevent,
# Nearest to are: adheres, adoption, kj, afrikaner, perfected, rapid, glad, predominant,
# Nearest to more: cinderella, burma, eia, anz, refuse, consultant, rohypnol, gypsy,
# Nearest to between: scales, contentious, of, amount, macroevolution, mental, brazil, ones,
# Nearest to time: theatres, insecurity, namesake, estimate, devote, consumed, garret, fantastic,
# Nearest to road: rector, islanders, cuttlefish, remarking, dixon, restrict, illusory, feeling,
# Nearest to instance: equation, statements, hops, recognizable, volatile, ulansey, desoto, aratus,
# Nearest to derived: direct, granada, homeowners, wight, endorsed, maser, premiers, bolder,
# Nearest to operating: jeep, patrolled, theoretic, goodyear, fiberglass, spartacist, judeans, hd,
# Nearest to placed: distance, even, staying, dagda, awe, kj, reception, cour,
# Nearest to troops: avenue, bram, priestly, slapped, terrain, wwii, hermeneutic, workshop,
# Nearest to professional: calves, gregorian, friedrich, ishmael, concepts, perutz, translation, dragon,
# Nearest to universe: drown, behave, inhabited, slapped, eram, altogether, bioko, greens,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7689 0.0307 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7412 0.0268 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7278 0.0269 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7218 0.0323 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7499 0.0266 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6818 0.0266 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6845 0.0273 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7236 0.0280 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7056 0.0261 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6632 0.0260 sec/batch
# Nearest to often: theory, traditional, writing, extended, stopped, adventures, gyges, macroscopic,
# Nearest to as: coalescence, sucessful, puppies, briefing, upper, mildly, ga, gymnasium,
# Nearest to called: indoctrination, hedging, age, coercive, plummer, chewed, reestablishing, structure,
# Nearest to states: saragossa, anonymously, jeffers, mortimer, biola, patriarchy, las, fraser,
# Nearest to are: adheres, adoption, kj, cosmodrome, glad, rapid, comparing, afrikaner,
# Nearest to more: cinderella, anz, eia, burma, rohypnol, consultant, adjudication, endurance,
# Nearest to between: scales, contentious, of, amount, brazil, og, mental, macroevolution,
# Nearest to time: theatres, namesake, insecurity, devote, garret, fantastic, vilnius, affiliation,
# Nearest to road: dixon, remarking, rector, islanders, cuttlefish, implicate, raider, sank,
# Nearest to instance: equation, statements, volatile, selectivity, recognizable, desoto, hops, ulansey,
# Nearest to derived: granada, direct, premiers, wight, homeowners, maser, substitutions, cameron,
# Nearest to operating: jeep, patrolled, sampler, goodyear, taxing, theoretic, spartacist, vegan,
# Nearest to placed: distance, even, dagda, cour, awe, staying, resistors, microscopes,
# Nearest to troops: bram, sardar, avenue, hermeneutic, priestly, encroached, terrain, mascarenhas,
# Nearest to professional: calves, friedrich, ishmael, gregorian, concepts, lvl, physiology, translation,
# Nearest to universe: drown, behave, shemot, bioko, slapped, eram, biologists, geneticists,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6626 0.0260 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6798 0.0252 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6160 0.0262 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6247 0.0248 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6369 0.0265 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6635 0.0259 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6097 0.0226 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5247 0.0263 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5118 0.0263 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5002 0.0291 sec/batch
# Nearest to often: theory, stopped, traditional, writing, abodes, macroscopic, warbeck, solver,
# Nearest to as: coalescence, a, mildly, coriolis, sucessful, emmett, click, jocular,
# Nearest to called: indoctrination, hedging, structure, coercive, age, plummer, geologic, vanished,
# Nearest to states: saragossa, fraser, jeffers, biola, mortimer, anonymously, las, patriarchy,
# Nearest to are: adheres, adoption, cosmodrome, comparing, kj, rapid, glad, update,
# Nearest to more: anz, cinderella, eia, burma, rohypnol, adjudication, endurance, mish,
# Nearest to between: scales, of, contentious, og, amount, macroevolution, mental, regional,
# Nearest to time: theatres, namesake, devote, insecurity, cluny, garret, affiliation, vilnius,
# Nearest to road: dixon, remarking, implicate, rector, sank, raider, codepoint, islanders,
# Nearest to instance: equation, statements, volatile, selectivity, recognizable, logical, concepts, compass,
# Nearest to derived: maser, granada, direct, substitutions, premiers, wight, gash, demonization,
# Nearest to operating: sampler, jeep, goodyear, patrolled, extrapolated, spartacist, reconsidered, taxing,
# Nearest to placed: distance, even, microscopes, dagda, awe, cour, iaido, debasing,
# Nearest to troops: sardar, bram, avenue, hermeneutic, battles, terrain, mascarenhas, encroached,
# Nearest to professional: calves, friedrich, concepts, malian, ishmael, intramuscular, lvl, molloy,
# Nearest to universe: drown, behave, biologists, eram, shemot, slapped, altogether, geneticists,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5116 0.0299 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4859 0.0287 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4424 0.0286 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5397 0.0287 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5012 0.0291 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4781 0.0296 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4690 0.0247 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4276 0.0261 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4232 0.0275 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4339 0.0284 sec/batch
# Nearest to often: theory, traditional, abodes, writing, during, stopped, unappealing, warbeck,
# Nearest to as: coriolis, coalescence, eeg, mildly, a, hyperbolic, jocular, sucessful,
# Nearest to called: indoctrination, hedging, structure, coercive, tentative, geologic, chewed, abbahu,
# Nearest to states: saragossa, jeffers, fraser, anonymously, mortimer, las, biola, prevent,
# Nearest to are: adheres, nickel, comparing, adoption, cosmodrome, rapid, provision, specialized,
# Nearest to more: anz, cinderella, eia, franchised, adjudication, chhattisgarh, rohypnol, burma,
# Nearest to between: scales, of, contentious, og, amount, brazil, macroevolution, tegmark,
# Nearest to time: theatres, namesake, devote, cluny, garret, mahathir, suites, vilnius,
# Nearest to road: dixon, raider, implicate, remarking, sank, codepoint, islanders, rector,
# Nearest to instance: equation, selectivity, statements, volatile, recognizable, logical, compass, concepts,
# Nearest to derived: maser, direct, substitutions, demonization, iis, granada, impossible, preserving,
# Nearest to operating: sampler, jeep, vendors, goodyear, extrapolated, programs, closed, hd,
# Nearest to placed: distance, even, iaido, microscopes, dagda, awe, cour, husky,
# Nearest to troops: sardar, avenue, battles, hermeneutic, bram, wwii, mascarenhas, terrain,
# Nearest to professional: calves, intramuscular, malian, ishmael, motivations, concepts, molloy, lvl,
# Nearest to universe: behave, drown, biologists, eram, zygote, methylation, grattan, shemot,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4236 0.0275 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4291 0.0276 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4640 0.0264 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3909 0.0255 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4352 0.0303 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4228 0.0269 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4052 0.0254 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4003 0.0253 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4332 0.0251 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3803 0.0253 sec/batch
# Nearest to often: traditional, writing, during, abodes, macroscopic, unappealing, pegmatite, fins,
# Nearest to as: coalescence, coriolis, a, emmett, eeg, sucessful, hyperbolic, puppies,
# Nearest to called: indoctrination, hedging, structure, abbahu, tentative, geologic, plummer, reestablishing,
# Nearest to states: saragossa, jeffers, anonymously, mortimer, biola, yuan, las, dost,
# Nearest to are: adheres, adoption, comparing, provision, cosmodrome, rapid, nickel, predominant,
# Nearest to more: anz, cinderella, eia, chhattisgarh, franchised, iterating, bundesverfassungsgericht, mish,
# Nearest to between: scales, contentious, of, og, amount, brazil, tegmark, macroevolution,
# Nearest to time: theatres, namesake, devote, mahathir, daglow, consumed, garret, testified,
# Nearest to road: dixon, implicate, raider, islanders, remarking, sank, crooked, codepoint,
# Nearest to instance: statements, equation, selectivity, volatile, logical, compass, concepts, ulansey,
# Nearest to derived: maser, direct, demonization, substitutions, iis, wight, preserving, accumulation,
# Nearest to operating: vendors, sampler, jeep, hd, programs, goodyear, dynamically, extrapolated,
# Nearest to placed: distance, even, microscopes, awe, iaido, staying, kj, dagda,
# Nearest to troops: battles, sardar, wwii, avenue, hermeneutic, mascarenhas, bram, ima,
# Nearest to professional: calves, motivations, intramuscular, concepts, molloy, ishmael, malian, residue,
# Nearest to universe: behave, biologists, drown, methylation, eram, zygote, grattan, geneticists,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3844 0.0276 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4124 0.0256 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3609 0.0281 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3623 0.0288 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4182 0.0274 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3674 0.0280 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4142 0.0295 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3566 0.0287 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3509 0.0262 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3531 0.0295 sec/batch
# Nearest to often: traditional, during, writing, abodes, pegmatite, plautus, extended, unappealing,
# Nearest to as: coriolis, eeg, a, puppies, presumes, emmett, coalescence, evident,
# Nearest to called: indoctrination, hedging, structure, tentative, geologic, abbahu, reestablishing, hypothesis,
# Nearest to states: saragossa, anonymously, jeffers, yuan, mortimer, dost, outmoded, biola,
# Nearest to are: adheres, comparing, nickel, cosmodrome, adoption, interact, provision, predominant,
# Nearest to more: anz, cinderella, eia, franchised, chhattisgarh, bundesverfassungsgericht, burma, adjudication,
# Nearest to between: scales, contentious, of, og, effluents, brazil, regional, since,
# Nearest to time: namesake, devote, theatres, daglow, affiliation, estimate, vilnius, garret,
# Nearest to road: raider, sank, dixon, implicate, islanders, crooked, remarking, codepoint,
# Nearest to instance: statements, selectivity, equation, logical, ulansey, compass, concepts, volatile,
# Nearest to derived: maser, demonization, direct, eradication, substitutions, preserving, wight, premiers,
# Nearest to operating: vendors, sampler, jeep, hd, programs, pilot, goodyear, windows,
# Nearest to placed: distance, even, microscopes, iaido, awe, alkalis, staying, resistors,
# Nearest to troops: battles, wwii, sardar, hermeneutic, siege, avenue, ima, border,
# Nearest to professional: calves, motivations, molloy, intramuscular, ishmael, malian, concepts, residue,
# Nearest to universe: behave, biologists, eram, methylation, drown, grattan, geneticists, shemot,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3610 0.0271 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3046 0.0275 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4075 0.0267 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4100 0.0262 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4034 0.0265 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3151 0.0275 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3468 0.0307 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3315 0.0278 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2126 0.0253 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3350 0.0279 sec/batch
# Nearest to often: traditional, during, writing, pegmatite, abodes, stopped, unappealing, dishes,
# Nearest to as: coriolis, eeg, coalescence, puppies, emmett, arcology, a, nordic,
# Nearest to called: indoctrination, hedging, structure, abbahu, hypothesis, geologic, tentative, plummer,
# Nearest to states: saragossa, yuan, anonymously, fraser, jeffers, biola, dost, las,
# Nearest to are: predominant, adheres, cosmodrome, nickel, adoption, rapid, interact, comparing,
# Nearest to more: anz, cinderella, eia, burma, bundesverfassungsgericht, chhattisgarh, franchised, mish,
# Nearest to between: scales, contentious, og, of, effluents, regional, tegmark, flanders,
# Nearest to time: devote, namesake, affiliation, theatres, garret, asprin, mahathir, cluny,
# Nearest to road: raider, sank, implicate, dixon, crooked, humber, beemer, codepoint,
# Nearest to instance: statements, selectivity, equation, arguments, logical, concepts, compass, holiness,
# Nearest to derived: demonization, maser, eradication, preserving, substitutions, wight, pronunciations, embellishments,
# Nearest to operating: vendors, sampler, windows, jeep, goodyear, hd, networking, programs,
# Nearest to placed: distance, microscopes, even, iaido, awe, alkalis, photoelectric, staying,
# Nearest to troops: wwii, battles, siege, sardar, border, mascarenhas, ima, hermeneutic,
# Nearest to professional: motivations, calves, molloy, malian, intramuscular, ishmael, concepts, tampere,
# Nearest to universe: biologists, drown, behave, grattan, methylation, shemot, geneticists, squaw,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3026 0.0286 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3128 0.0273 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3322 0.0107 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2356 0.0264 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2471 0.0280 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2416 0.0259 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2193 0.0259 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1942 0.0265 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2197 0.0262 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1527 0.0240 sec/batch
# Nearest to often: traditional, during, writing, pegmatite, abodes, dishes, stopped, warbeck,
# Nearest to as: coriolis, arcology, emmett, eeg, nordic, a, engined, coalescence,
# Nearest to called: indoctrination, hedging, structure, hypothesis, geologic, tentative, abbahu, warts,
# Nearest to states: yuan, anonymously, saragossa, dost, las, aurangabad, jeffers, prevent,
# Nearest to are: predominant, nickel, duals, adheres, cosmodrome, adoption, is, whereas,
# Nearest to more: anz, eia, cinderella, chhattisgarh, burma, bundesverfassungsgericht, vastly, franchised,
# Nearest to between: scales, tegmark, og, effluents, contentious, of, brazil, regional,
# Nearest to time: victory, devote, namesake, garret, asprin, theatres, motorsports, mahathir,
# Nearest to road: raider, sank, crooked, implicate, beemer, codepoint, humber, autos,
# Nearest to instance: statements, selectivity, equation, logical, arguments, concepts, ulansey, holiness,
# Nearest to derived: maser, pronunciations, demonization, jamnia, preserving, eradication, embellishments, wight,
# Nearest to operating: vendors, sampler, motorola, microprocessors, jeep, os, windows, versions,
# Nearest to placed: distance, microscopes, even, iaido, alkalis, awe, staying, besieged,
# Nearest to troops: wwii, battles, siege, sardar, terrain, battle, fighters, crashes,
# Nearest to professional: motivations, molloy, calves, wins, malian, concepts, intramuscular, tampere,
# Nearest to universe: biologists, drown, grattan, behave, geneticists, shemot, methylation, clearly,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2419 0.0287 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2071 0.0275 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2446 0.0262 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1402 0.0242 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1753 0.0260 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1680 0.0251 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1589 0.0249 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2075 0.0253 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2011 0.0275 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1810 0.0304 sec/batch
# Nearest to often: traditional, during, writing, abodes, dishes, pegmatite, stopped, fins,
# Nearest to as: coriolis, eeg, arcology, a, coalescence, nordic, hyperbolic, tweaking,
# Nearest to called: structure, hedging, indoctrination, warts, tentative, hypothesis, geologic, abbahu,
# Nearest to states: anonymously, yuan, dost, aurangabad, saragossa, jeffers, admitting, steinbeck,
# Nearest to are: predominant, duals, is, interact, whereas, adheres, nickel, rigid,
# Nearest to more: anz, chhattisgarh, cinderella, bundesverfassungsgericht, eia, vastly, franchised, burma,
# Nearest to between: scales, tegmark, contentious, effluents, og, regional, of, macroevolution,
# Nearest to time: asprin, victory, devote, theatres, namesake, garret, motorsports, mahathir,
# Nearest to road: raider, sank, beemer, crooked, autos, codepoint, oregano, humber,
# Nearest to instance: statements, selectivity, equation, logical, arguments, holiness, ulansey, concepts,
# Nearest to derived: maser, demonization, pronunciations, jamnia, substitutions, preserving, eradication, embellishments,
# Nearest to operating: vendors, sampler, jeep, microprocessors, batch, networking, goodyear, motorola,
# Nearest to placed: distance, microscopes, iaido, even, alkalis, awe, staying, photoelectric,
# Nearest to troops: wwii, battles, siege, sardar, armistice, hermeneutic, battle, terrain,
# Nearest to professional: motivations, molloy, calves, malian, wins, intramuscular, leading, sidgwick,
# Nearest to universe: biologists, drown, bang, grattan, behave, shemot, clearly, geneticists,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1979 0.0279 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2168 0.0277 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1983 0.0288 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1957 0.0272 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1989 0.0288 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1962 0.0252 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1959 0.0257 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1540 0.0264 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1482 0.0304 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1973 0.0264 sec/batch
# Nearest to often: traditional, dishes, abodes, writing, pegmatite, during, plautus, plastids,
# Nearest to as: coriolis, emmett, eeg, is, a, coalescence, nordic, hyperbolic,
# Nearest to called: hedging, structure, indoctrination, tentative, warts, philippians, reestablishing, geologic,
# Nearest to states: dost, yuan, harar, aurangabad, anonymously, saragossa, steinbeck, jeffers,
# Nearest to are: duals, predominant, is, adoption, adheres, interact, consists, cosmodrome,
# Nearest to more: anz, vastly, chhattisgarh, bundesverfassungsgericht, franchised, eia, cinderella, burma,
# Nearest to between: scales, tegmark, og, contentious, effluents, astigmatism, klux, solid,
# Nearest to time: garret, devote, asprin, theatres, namesake, victory, affiliation, estimate,
# Nearest to road: raider, sank, humber, beemer, crooked, autos, codepoint, implicate,
# Nearest to instance: statements, selectivity, equation, logical, ulansey, arguments, holiness, computationally,
# Nearest to derived: pronunciations, maser, demonization, eradication, jamnia, preserving, embellishments, evolved,
# Nearest to operating: vendors, sampler, jeep, goodyear, batch, hd, retain, fiberglass,
# Nearest to placed: distance, microscopes, iaido, even, staying, alkalis, jumps, awe,
# Nearest to troops: wwii, battles, siege, sardar, armistice, strategic, fighters, mascarenhas,
# Nearest to professional: motivations, molloy, leading, calves, wins, concepts, intramuscular, malian,
# Nearest to universe: drown, bang, grattan, shemot, biologists, behave, geneticists, stephen,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2384 0.0281 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1675 0.0293 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1694 0.0274 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1852 0.0257 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1771 0.0277 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1476 0.0275 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1564 0.0273 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1200 0.0265 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1850 0.0282 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2143 0.0291 sec/batch
# Nearest to often: traditional, writing, dishes, during, abodes, plautus, plastids, pegmatite,
# Nearest to as: emmett, nordic, coriolis, a, mccain, undermine, is, eeg,
# Nearest to called: hedging, philippians, partisans, reestablishing, indoctrination, abbahu, structure, tentative,
# Nearest to states: dost, harar, yuan, steinbeck, aurangabad, amendment, anonymously, admitting,
# Nearest to are: predominant, is, duals, consists, adheres, interact, adoption, deduction,
# Nearest to more: anz, chhattisgarh, bundesverfassungsgericht, eia, cinderella, burma, vastly, franchised,
# Nearest to between: scales, contentious, effluents, og, tegmark, klux, flanders, duchy,
# Nearest to time: devote, namesake, victory, garret, asprin, affiliation, theatres, mahathir,
# Nearest to road: raider, humber, sank, crooked, beemer, implicate, codepoint, autos,
# Nearest to instance: statements, selectivity, dressers, wrongs, ulansey, equation, arguments, holiness,
# Nearest to derived: pronunciations, maser, demonization, jamnia, eradication, preserving, sup, typed,
# Nearest to operating: vendors, jeep, goodyear, sampler, windows, batch, unix, hd,
# Nearest to placed: distance, microscopes, iaido, awe, even, jumps, helping, staying,
# Nearest to troops: wwii, battles, siege, sardar, strategic, fighters, mascarenhas, armistice,
# Nearest to professional: motivations, molloy, wins, calves, leading, sidgwick, malian, tippit,
# Nearest to universe: drown, grattan, shemot, bang, biologists, rhett, behave, geneticists,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2456 0.0298 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1864 0.0273 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1659 0.0257 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1880 0.0248 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0618 0.0303 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1655 0.0274 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1935 0.0260 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1423 0.0267 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1690 0.0052 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1477 0.0261 sec/batch
# Nearest to often: traditional, writing, dishes, during, abodes, pegmatite, cetaceans, plautus,
# Nearest to as: coriolis, emmett, arcology, eeg, is, a, regional, engined,
# Nearest to called: hedging, structure, philippians, reestablishing, geologic, abbahu, pegasi, vanished,
# Nearest to states: harar, dost, aurangabad, steinbeck, yuan, admitting, amendment, prevent,
# Nearest to are: is, predominant, consists, duals, interact, adheres, other, adoption,
# Nearest to more: anz, bundesverfassungsgericht, eia, chhattisgarh, vastly, kib, burma, puttnam,
# Nearest to between: scales, og, tegmark, effluents, of, contentious, southerly, klux,
# Nearest to time: devote, asprin, victory, seconds, namesake, garret, estimate, affiliation,
# Nearest to road: raider, humber, beemer, crooked, autos, implicate, friday, codepoint,
# Nearest to instance: statements, selectivity, wrongs, arguments, equation, ulansey, dressers, holiness,
# Nearest to derived: pronunciations, standardised, jamnia, demonization, eradication, sup, maser, theremin,
# Nearest to operating: vendors, jeep, unix, versions, goodyear, batch, os, sampler,
# Nearest to placed: distance, microscopes, iaido, even, alkalis, jumps, awe, helping,
# Nearest to troops: wwii, battles, siege, sardar, fighters, mascarenhas, armistice, border,
# Nearest to professional: motivations, molloy, wins, leading, concepts, calves, intramuscular, sidgwick,
# Nearest to universe: drown, shemot, grattan, geneticists, bang, rhett, biologists, stephen,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0905 0.0279 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0882 0.0281 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1019 0.0318 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0624 0.0270 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0854 0.0272 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0422 0.0296 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1217 0.0299 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1267 0.0256 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1166 0.0255 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0572 0.0259 sec/batch
# Nearest to often: traditional, writing, dishes, abodes, during, pegmatite, cetaceans, spawning,
# Nearest to as: a, coriolis, is, arcology, eeg, emmett, such, regional,
# Nearest to called: structure, hedging, partisans, philippians, reestablishing, pegasi, whose, indoctrination,
# Nearest to states: admitting, aurangabad, harar, prevent, eas, dost, steinbeck, rocha,
# Nearest to are: is, predominant, consists, duals, interact, other, some, rigid,
# Nearest to more: anz, bundesverfassungsgericht, eia, chhattisgarh, kib, franchised, puttnam, assemblage,
# Nearest to between: scales, of, effluents, tegmark, southerly, og, brazil, contentious,
# Nearest to time: victory, devote, asprin, namesake, garret, seconds, theatres, mahathir,
# Nearest to road: raider, beemer, humber, autos, crooked, friday, yarmouth, metro,
# Nearest to instance: selectivity, statements, wrongs, arguments, equation, ulansey, dressers, computationally,
# Nearest to derived: pronunciations, standardised, theremin, maser, demonization, embellishments, wight, jamnia,
# Nearest to operating: vendors, batch, jeep, unix, goodyear, sampler, retain, versions,
# Nearest to placed: distance, microscopes, iaido, even, jumps, staying, besieged, alkalis,
# Nearest to troops: wwii, battles, fighters, siege, armistice, sardar, causing, border,
# Nearest to professional: motivations, molloy, wins, calves, concepts, calico, leading, intramuscular,
# Nearest to universe: drown, bang, grattan, shemot, cosmic, blackbody, geneticists, behave,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0365 0.0311 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0584 0.0270 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0240 0.0285 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0568 0.0260 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0879 0.0281 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0717 0.0256 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0846 0.0271 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1010 0.0264 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0457 0.0251 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0597 0.0269 sec/batch
# Nearest to often: traditional, writing, cetaceans, spawning, dishes, abodes, tones, special,
# Nearest to as: coriolis, a, is, such, eeg, coalescence, emmett, brahmi,
# Nearest to called: structure, partisans, philippians, hedging, indoctrination, whose, pegasi, tentative,
# Nearest to states: admitting, amendment, aurangabad, dost, yuan, biola, rocha, eas,
# Nearest to are: is, consists, other, duals, predominant, interact, some, adheres,
# Nearest to more: anz, kib, bundesverfassungsgericht, eia, chhattisgarh, franchised, hip, vastly,
# Nearest to between: scales, of, og, effluents, tegmark, solid, contentious, southerly,
# Nearest to time: namesake, devote, quad, victory, theatres, seconds, garret, mahathir,
# Nearest to road: raider, humber, beemer, autos, friday, crooked, metro, yarmouth,
# Nearest to instance: selectivity, statements, equation, dressers, arguments, ulansey, wrongs, computationally,
# Nearest to derived: standardised, pronunciations, maser, theremin, sup, jamnia, rosicrucians, demonization,
# Nearest to operating: vendors, batch, jeep, unix, sampler, goodyear, retain, dynamically,
# Nearest to placed: distance, microscopes, iaido, jumps, alkalis, cour, symmetrically, chlorides,
# Nearest to troops: wwii, siege, armistice, battles, border, sardar, shrunk, mascarenhas,
# Nearest to professional: motivations, molloy, calico, leading, nationalised, associations, wins, malian,
# Nearest to universe: drown, bang, grattan, shemot, clearly, stephen, asserted, geneticists,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0579 0.0318 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0966 0.0333 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0820 0.0284 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0778 0.0298 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0540 0.0286 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0885 0.0257 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0704 0.0294 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0636 0.0288 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1026 0.0299 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0880 0.0287 sec/batch
# Nearest to often: traditional, cetaceans, writing, abodes, pegmatite, plautus, dishes, spawning,
# Nearest to as: coriolis, a, undermine, emmett, eeg, is, brahmi, slavic,
# Nearest to called: structure, partisans, philippians, tentative, whose, hedging, indoctrination, reestablishing,
# Nearest to states: admitting, aurangabad, amendment, dost, enforcement, biola, eas, rocha,
# Nearest to are: is, consists, other, predominant, registration, adheres, some, duals,
# Nearest to more: anz, chhattisgarh, hip, kib, puttnam, bundesverfassungsgericht, eia, shir,
# Nearest to between: scales, of, effluents, contentious, og, spartans, flanders, klux,
# Nearest to time: devote, namesake, victory, declared, estimate, seconds, affiliation, escalating,
# Nearest to road: raider, humber, autos, beemer, crooked, friday, taxis, pont,
# Nearest to instance: dressers, statements, selectivity, wrongs, ulansey, arguments, holiness, equation,
# Nearest to derived: pronunciations, standardised, theremin, maser, sup, hih, evolved, eradication,
# Nearest to operating: vendors, batch, jeep, goodyear, sampler, retain, unix, aldine,
# Nearest to placed: distance, microscopes, iaido, jumps, alkalis, helping, even, cour,
# Nearest to troops: wwii, siege, border, battles, armistice, sardar, causing, shrunk,
# Nearest to professional: motivations, molloy, associations, calico, tippit, intermingle, calves, sidgwick,
# Nearest to universe: drown, bang, grattan, shemot, asserted, stephen, rhett, lanham,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0888 0.0303 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0524 0.0278 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0602 0.0267 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0323 0.0292 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1088 0.0280 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1200 0.0303 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1287 0.0260 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0552 0.0261 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0427 0.0261 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0548 0.0258 sec/batch
# Nearest to often: traditional, cetaceans, dishes, writing, canvases, spawning, plautus, abodes,
# Nearest to as: emmett, a, coriolis, eeg, undermine, broadcasters, brahmi, such,
# Nearest to called: structure, partisans, hedging, philippians, whose, dawson, tentative, vanished,
# Nearest to states: admitting, amendment, aurangabad, prevent, enforcement, biola, dost, anonymously,
# Nearest to are: is, consists, predominant, other, adheres, interact, some, duals,
# Nearest to more: anz, chhattisgarh, kib, puttnam, bundesverfassungsgericht, assemblage, covalent, mucilage,
# Nearest to between: of, scales, og, southerly, effluents, borders, contentious, tegmark,
# Nearest to time: devote, namesake, seconds, quad, escalating, affiliation, victory, consumed,
# Nearest to road: raider, autos, humber, friday, crooked, beemer, taxis, pont,
# Nearest to instance: wrongs, arguments, statements, selectivity, dressers, equation, subject, ulansey,
# Nearest to derived: standardised, theremin, pronunciations, maser, sup, hih, josephus, eradication,
# Nearest to operating: vendors, goodyear, batch, jeep, sampler, unix, retain, packaging,
# Nearest to placed: distance, microscopes, cour, jumps, helping, iaido, even, chlorides,
# Nearest to troops: wwii, border, siege, armistice, sardar, aristide, battles, mascarenhas,
# Nearest to professional: motivations, molloy, associations, acrobatic, tippit, calves, sidgwick, calico,
# Nearest to universe: drown, bang, grattan, stephen, shemot, lanham, asserted, rhett,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9832 0.0257 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0381 0.0261 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0225 0.0244 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0376 0.0269 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0871 0.0270 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0498 0.0256 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0174 0.0274 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9816 0.0270 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0306 0.0288 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9768 0.0251 sec/batch
# Nearest to often: traditional, cetaceans, canvases, writing, tones, hilltops, dishes, constantly,
# Nearest to as: a, coriolis, emmett, brahmi, undermine, eeg, regional, named,
# Nearest to called: structure, philippians, hedging, partisans, whose, struct, compound, illyrians,
# Nearest to states: admitting, aurangabad, amendment, rocha, dost, eas, anonymously, biola,
# Nearest to are: is, consists, other, predominant, interact, duals, excelsa, trees,
# Nearest to more: anz, chhattisgarh, kib, bundesverfassungsgericht, eia, puttnam, mucilage, unregistered,
# Nearest to between: of, scales, og, southerly, borders, effluents, tegmark, solid,
# Nearest to time: devote, namesake, garret, seconds, victory, quad, affiliation, consumed,
# Nearest to road: raider, autos, humber, friday, beemer, crooked, taxis, rooms,
# Nearest to instance: wrongs, dressers, selectivity, arguments, statements, equation, ulansey, subject,
# Nearest to derived: standardised, theremin, maser, beyond, sup, pronunciations, hih, josephus,
# Nearest to operating: vendors, batch, unix, sampler, goodyear, jeep, retain, os,
# Nearest to placed: distance, microscopes, cour, jumps, iaido, helping, sit, duna,
# Nearest to troops: wwii, border, siege, armistice, battles, aristide, sardar, alamein,
# Nearest to professional: motivations, molloy, associations, tippit, intermingle, acrobatic, polytechnics, calves,
# Nearest to universe: drown, bang, shemot, lanham, grattan, stephen, asserted, teachings,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0014 0.0254 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9756 0.0266 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0155 0.0266 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0497 0.0279 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0190 0.0266 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0037 0.0294 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9361 0.0306 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9788 0.0279 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9864 0.0279 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9796 0.0317 sec/batch
# Nearest to often: traditional, cetaceans, dishes, cameroun, canvases, hilltops, from, constantly,
# Nearest to as: a, such, regional, is, today, brahmi, the, coriolis,
# Nearest to called: structure, whose, partisans, philippians, hedging, struct, when, illyrians,
# Nearest to states: admitting, enforcement, prevent, rocha, aurangabad, anonymously, biola, amendment,
# Nearest to are: is, consists, other, interact, or, excelsa, duals, some,
# Nearest to more: anz, kib, chhattisgarh, covalent, mucilage, unregistered, bundesverfassungsgericht, assemblage,
# Nearest to between: of, scales, southerly, effluents, og, solid, borders, tegmark,
# Nearest to time: quad, devote, namesake, seconds, victory, faced, trade, mahathir,
# Nearest to road: raider, autos, friday, humber, beemer, rooms, taxis, crooked,
# Nearest to instance: selectivity, dressers, arguments, wrongs, equation, statements, ulansey, ovary,
# Nearest to derived: standardised, maser, theremin, hih, sup, evolved, josephus, beyond,
# Nearest to operating: batch, vendors, unix, jeep, goodyear, sampler, retain, hyundai,
# Nearest to placed: distance, microscopes, cour, jumps, iaido, duna, helping, alkalis,
# Nearest to troops: wwii, armistice, aristide, border, alamein, battles, siege, shrunk,
# Nearest to professional: motivations, molloy, associations, acrobatic, intermingle, polytechnics, tippit, calves,
# Nearest to universe: drown, bang, stephen, lensing, cosmic, grattan, shemot, anthropic,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0149 0.0299 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0331 0.0299 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9722 0.0270 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0463 0.0276 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0437 0.0248 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9610 0.0266 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0329 0.0255 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0264 0.0255 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9905 0.0257 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0560 0.0267 sec/batch
# Nearest to often: traditional, cetaceans, special, cameroun, canvases, from, plautus, writing,
# Nearest to as: a, emmett, regional, the, all, brahmi, eeg, such,
# Nearest to called: structure, whose, philippians, partisans, hedging, tentative, strand, plaid,
# Nearest to states: admitting, amendment, biola, rocha, enforcement, aurangabad, eas, anonymously,
# Nearest to are: is, consists, other, interact, or, some, registration, negro,
# Nearest to more: anz, kib, chhattisgarh, puttnam, hip, mucilage, assemblage, half,
# Nearest to between: of, scales, og, characterizing, tegmark, minter, klux, southerly,
# Nearest to time: quad, faced, seconds, devote, namesake, victory, garret, declared,
# Nearest to road: autos, raider, humber, rooms, beemer, taxis, friday, crooked,
# Nearest to instance: equation, wrongs, dressers, arguments, selectivity, ulansey, subject, statements,
# Nearest to derived: standardised, maser, evolved, beyond, hih, theremin, josephus, sup,
# Nearest to operating: batch, vendors, jeep, goodyear, sampler, unix, retain, cameroonian,
# Nearest to placed: distance, microscopes, cour, jumps, helping, iaido, sit, staying,
# Nearest to troops: wwii, armistice, aristide, border, soldier, alamein, siege, shrunk,
# Nearest to professional: motivations, molloy, associations, acrobatic, tippit, polytechnics, gillmor, sidgwick,
# Nearest to universe: bang, drown, stephen, cosmic, lensing, grattan, lanham, anthropic,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0245 0.0270 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9983 0.0295 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9993 0.0258 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0326 0.0269 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0233 0.0253 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9863 0.0274 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9934 0.0285 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9950 0.0286 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0049 0.0282 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0454 0.0280 sec/batch
# Nearest to often: traditional, cetaceans, from, hilltops, pegmatite, constantly, mainly, abodes,
# Nearest to as: a, the, brahmi, is, and, regional, named, emmett,
# Nearest to called: structure, partisans, whose, philippians, hedging, apostolicae, illyrians, strand,
# Nearest to states: admitting, united, enforcement, amendment, dost, eas, biola, aurangabad,
# Nearest to are: is, other, consists, some, adheres, or, excelsa, registration,
# Nearest to more: anz, kib, chhattisgarh, half, puttnam, assemblage, with, mucilage,
# Nearest to between: of, scales, borders, the, effluents, a, part, og,
# Nearest to time: seconds, declared, buraku, consumed, faced, devote, estimate, gifts,
# Nearest to road: autos, raider, humber, taxis, rooms, beemer, friday, pont,
# Nearest to instance: dressers, wrongs, equation, arguments, ulansey, subject, selectivity, statements,
# Nearest to derived: standardised, maser, theremin, evolved, josephus, sup, beyond, modifier,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8543 0.0294 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8729 0.0288 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9426 0.0287 sec/batch
# Nearest to often: traditional, as, referred, known, cetaceans, from, special, mainly,
# Nearest to as: a, in, the, and, of, such, to, also,
# Nearest to called: whose, in, when, the, was, lyricists, has, apostolicae,
# Nearest to states: united, america, us, milton, biola, admitting, countries, virginia,
# Nearest to are: is, or, some, other, and, consists, with, of,
# Nearest to more: than, anz, with, a, achieve, in, kib, achieved,
# Nearest to between: and, of, in, the, a, part, borders, to,
# Nearest to time: began, several, seconds, when, that, syllogisms, as, attention,
# Nearest to road: autos, humber, beemer, raider, oat, taxis, codepoint, exit,
# Nearest to instance: incomprehensible, irrespective, aussie, wrongs, arguments, plaintexts, ovary, subject,
# Nearest to derived: capriccio, standardised, superfluidity, theremin, evolved, sup, formosa, simplifications,
# Nearest to operating: unix, batch, cameroonian, goodyear, sampler, saved, gib, gb,
# Nearest to placed: cour, distance, trimming, menu, snake, microscopes, symmetrically, helping,
# Nearest to troops: memoirs, grenade, alamein, forces, avenue, soldier, armistice, encircle,
# Nearest to professional: association, technical, polytechnics, american, molloy, tippit, diploma, associations,
# Nearest to universe: bang, drown, fun, consultancies, lensing, presumes, gujarat, cosmic,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8440 0.0304 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8457 0.0287 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8624 0.0263 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8731 0.0260 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8630 0.0275 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8867 0.0281 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8848 0.0278 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8696 0.0263 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9131 0.0269 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8721 0.0280 sec/batch
# Nearest to often: traditional, as, referred, cetaceans, mainly, from, pegmatite, known,
# Nearest to as: a, in, the, and, of, to, also, all,
# Nearest to called: whose, structure, when, has, apostolicae, groups, the, is,
# Nearest to states: united, america, us, countries, u, amendment, enforcement, intakes,
# Nearest to are: is, other, or, some, consists, and, with, of,
# Nearest to more: than, anz, with, in, to, a, achieve, kib,
# Nearest to between: and, of, in, the, a, part, borders, to,
# Nearest to time: began, several, seconds, attention, syllogisms, buraku, illiteracy, when,
# Nearest to road: autos, humber, raider, beemer, oat, taxis, exit, codepoint,
# Nearest to instance: arguments, incomprehensible, wrongs, irrespective, aussie, plaintexts, subject, ovary,
# Nearest to derived: evolved, formosa, capriccio, standardised, theremin, superfluidity, sup, josephus,
# Nearest to operating: unix, batch, goodyear, cameroonian, sampler, saved, gib, empress,
# Nearest to placed: cour, trimming, distance, microscopes, snake, helping, menu, margrethe,
# Nearest to troops: memoirs, forces, grenade, alamein, avenue, soldier, border, aristide,
# Nearest to professional: association, polytechnics, technical, molloy, tippit, american, motivations, acrobatic,
# Nearest to universe: bang, lensing, drown, consultancies, fun, cosmic, presumes, ghb,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8862 0.0297 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8892 0.0277 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8701 0.0282 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8666 0.0264 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9093 0.0286 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8361 0.0275 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9703 0.0257 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9118 0.0300 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9184 0.0293 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8535 0.0274 sec/batch
# Nearest to often: traditional, as, referred, from, mainly, pegmatite, cetaceans, widely,
# Nearest to as: a, the, in, and, of, to, also, such,
# Nearest to called: whose, has, the, when, was, in, structure, partisans,
# Nearest to states: united, countries, america, us, u, milton, the, amendment,
# Nearest to are: is, other, or, consists, some, the, and, of,
# Nearest to more: than, in, anz, to, a, with, these, of,
# Nearest to between: and, of, in, part, borders, the, a, to,
# Nearest to time: began, seconds, several, during, when, syllogisms, schisms, attention,
# Nearest to road: autos, humber, raider, beemer, taxis, oat, exit, codepoint,
# Nearest to instance: arguments, wrongs, irrespective, incomprehensible, aussie, enforcers, subject, plaintexts,
# Nearest to derived: capriccio, theremin, standardised, this, sup, superfluidity, evolved, formosa,
# Nearest to operating: unix, batch, cameroonian, goodyear, saved, empress, icrc, patrolled,
# Nearest to placed: cour, trimming, distance, helping, snake, menu, sledge, legitimacy,
# Nearest to troops: memoirs, forces, grenade, negotiate, alamein, massacre, avenue, soldier,
# Nearest to professional: association, polytechnics, technical, american, molloy, natalie, tippit, motivations,
# Nearest to universe: bang, drown, lensing, consultancies, fun, cosmic, presumes, grundgesetz,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8046 0.0268 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8927 0.0287 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8148 0.0306 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8772 0.0308 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8525 0.0263 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8830 0.0274 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9340 0.0140 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8575 0.0282 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8376 0.0286 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8723 0.0263 sec/batch
# Nearest to often: traditional, cetaceans, as, referred, pegmatite, mainly, known, widely,
# Nearest to as: a, and, the, in, to, such, of, all,
# Nearest to called: whose, the, has, was, in, structure, approximately, when,
# Nearest to states: united, us, countries, milton, u, america, amendment, intakes,
# Nearest to are: or, is, other, consists, some, and, with, the,
# Nearest to more: than, to, anz, achieved, in, these, a, assemblage,
# Nearest to between: and, of, in, the, a, part, borders, to,
# Nearest to time: began, during, several, seconds, syllogisms, when, according, buraku,
# Nearest to road: autos, humber, raider, beemer, oat, taxis, vinnie, exit,
# Nearest to instance: arguments, incomprehensible, aussie, irrespective, wrongs, enforcers, ovary, gamecube,
# Nearest to derived: capriccio, formosa, standardised, theremin, sup, rather, superfluidity, this,
# Nearest to operating: unix, batch, cameroonian, interactivity, icrc, empress, gib, goodyear,
# Nearest to placed: cour, distance, trimming, helping, snake, sledge, loomis, legitimacy,
# Nearest to troops: forces, massacre, memoirs, soldier, avenue, ldap, negotiate, xzibit,
# Nearest to professional: association, technical, molloy, polytechnics, natalie, american, tippit, weert,
# Nearest to universe: bang, drown, fun, lensing, presumes, consultancies, contradict, grundgesetz,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8395 0.0284 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8244 0.0284 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8307 0.0279 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8259 0.0273 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8594 0.0258 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8514 0.0263 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8961 0.0282 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7841 0.0260 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8436 0.0238 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8098 0.0260 sec/batch
# Nearest to often: traditional, as, referred, from, known, widely, sometimes, cetaceans,
# Nearest to as: a, in, the, and, to, of, such, used,
# Nearest to called: whose, in, the, has, was, a, structure, groups,
# Nearest to states: united, us, countries, milton, america, u, intakes, biola,
# Nearest to are: is, other, or, some, consists, and, with, of,
# Nearest to more: than, in, a, to, well, of, anz, these,
# Nearest to between: and, of, in, the, a, part, borders, as,
# Nearest to time: began, during, syllogisms, that, several, seconds, when, according,
# Nearest to road: autos, humber, beemer, raider, taxis, oat, exit, winding,
# Nearest to instance: arguments, incomprehensible, aussie, irrespective, plaintexts, enforcers, wrongs, subject,
# Nearest to derived: this, superfluidity, theremin, capriccio, sup, rather, standardised, in,
# Nearest to operating: unix, batch, cameroonian, saved, interactivity, gib, patrolled, goodyear,
# Nearest to placed: cour, distance, trimming, symmetrically, snake, sledge, legitimacy, microscopes,
# Nearest to troops: forces, alamein, massacre, memoirs, grenade, soldier, vietnam, encircle,
# Nearest to professional: association, technical, polytechnics, molloy, bodybuilders, american, weert, intermingle,
# Nearest to universe: bang, drown, lensing, consultancies, anthropic, presumes, fun, cosmic,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7772 0.0281 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8358 0.0259 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8606 0.0269 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8470 0.0249 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8396 0.0264 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9295 0.0264 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8496 0.0254 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8571 0.0290 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8462 0.0278 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8696 0.0279 sec/batch
# Nearest to often: traditional, as, known, referred, from, mainly, widely, sometimes,
# Nearest to as: a, the, in, and, of, such, is, to,
# Nearest to called: whose, the, was, has, a, is, in, an,
# Nearest to states: united, us, america, countries, biola, amendment, u, milton,
# Nearest to are: other, is, or, some, with, consists, and, have,
# Nearest to more: in, than, to, anz, with, a, well, these,
# Nearest to between: and, of, in, a, the, an, borders, part,
# Nearest to time: began, during, seconds, several, syllogisms, that, when, as,
# Nearest to road: humber, autos, raider, beemer, oat, taxis, clockmaker, exit,
# Nearest to instance: arguments, incomprehensible, irrespective, subject, aussie, plaintexts, wrongs, gamecube,
# Nearest to derived: this, capriccio, josephus, standardised, sup, formosa, rather, in,
# Nearest to operating: unix, batch, patrolled, saved, cameroonian, sampler, gib, interactivity,
# Nearest to placed: cour, trimming, distance, snake, symmetrically, menu, microscopes, sledge,
# Nearest to troops: forces, grenade, alamein, memoirs, encircle, detachment, border, soldier,
# Nearest to professional: association, technical, polytechnics, bodybuilders, molloy, american, diploma, weert,
# Nearest to universe: bang, drown, lensing, anthropic, consultancies, fun, cosmic, presumes,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9189 0.0293 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8517 0.0252 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8389 0.0256 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8627 0.0251 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8743 0.0248 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8613 0.0253 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8505 0.0270 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8557 0.0304 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8548 0.0280 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8154 0.0247 sec/batch
# Nearest to often: traditional, as, referred, from, known, sometimes, widely, pegmatite,
# Nearest to as: in, the, a, and, of, to, is, used,
# Nearest to called: the, whose, in, has, a, is, was, an,
# Nearest to states: united, countries, us, america, u, violates, amendment, intakes,
# Nearest to are: is, other, or, some, and, consists, with, of,
# Nearest to more: in, than, these, to, a, well, with, an,
# Nearest to between: and, of, in, a, part, the, borders, an,
# Nearest to time: began, during, as, several, seconds, when, that, schisms,
# Nearest to road: humber, autos, beemer, raider, taxis, oat, exit, route,
# Nearest to instance: arguments, incomprehensible, aussie, wrongs, plaintexts, subject, irrespective, gamecube,
# Nearest to derived: this, rather, superfluidity, in, capriccio, evolved, sup, kennings,
# Nearest to operating: unix, batch, cameroonian, patrolled, saved, goodyear, empress, gib,
# Nearest to placed: trimming, cour, distance, snake, legitimacy, helping, menu, symmetrically,
# Nearest to troops: forces, encircle, memoirs, grenade, alamein, siege, border, detachment,
# Nearest to professional: association, technical, polytechnics, molloy, natalie, tippit, american, bodybuilders,
# Nearest to universe: bang, drown, lensing, anthropic, consultancies, presumes, fun, ghb,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8832 0.0298 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8574 0.0273 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9378 0.0266 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8984 0.0261 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9142 0.0264 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8545 0.0266 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8090 0.0288 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8591 0.0264 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7799 0.0261 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8895 0.0283 sec/batch
# Nearest to often: traditional, as, referred, known, sometimes, mainly, from, pegmatite,
# Nearest to as: in, a, the, and, such, of, to, also,
# Nearest to called: the, whose, in, has, was, a, is, an,
# Nearest to states: united, us, u, america, countries, milton, amendment, overdose,
# Nearest to are: is, other, or, some, consists, and, with, the,
# Nearest to more: in, than, to, these, a, anz, of, with,
# Nearest to between: and, of, in, the, a, borders, part, an,
# Nearest to time: began, during, seconds, when, several, schisms, syllogisms, illiteracy,
# Nearest to road: humber, autos, raider, oat, taxis, beemer, winding, clockmaker,
# Nearest to instance: arguments, aussie, incomprehensible, wrongs, plaintexts, gamecube, irrespective, primitives,
# Nearest to derived: josephus, capriccio, this, premiers, sup, nesbitt, superfluidity, formosa,
# Nearest to operating: unix, batch, cameroonian, saved, icrc, patrolled, packaging, gib,
# Nearest to placed: distance, trimming, cour, snake, legitimacy, symmetrically, sledge, menu,
# Nearest to troops: forces, encircle, memoirs, grenade, siege, avenue, alamein, border,
# Nearest to professional: technical, association, natalie, molloy, tippit, polytechnics, weert, american,
# Nearest to universe: bang, drown, lensing, anthropic, consultancies, fun, contradict, presumes,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8578 0.0284 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8676 0.0276 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
